# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

# %%
df = pd.read_csv('../data/yield_final.csv')

# %%
df_new = df.copy() 

df_new.yield_hg_ha = np.log1p(df_new.yield_hg_ha) 
df_new.avg_temp = np.log1p(df_new.avg_temp) 
df_new.pesticide_tonnes = np.log1p(df_new.pesticide_tonnes) 
df_new.average_rain_fall_mm_per_year = np.log1p(df_new.average_rain_fall_mm_per_year)

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df_new[['yield_hg_ha', 'average_rain_fall_mm_per_year', 
                                           'pesticide_tonnes', 'avg_temp']])

# %%
scaled_features
# Out:
# array([[-0.09723185,  0.60758128, -1.04512886, -0.28578959],
#        [-0.30115772,  0.60758128, -1.04512886, -0.43694743],
#        [-0.43877828,  0.60758128, -1.04512886, -0.33122895],
#        ...,
#        [-0.57356093, -0.32217428,  0.06900797,  0.29136434],
#        [-0.63929358, -0.32217428,  0.06900797,  0.29136434],
#        [-0.71035959, -0.32217428,  0.06900797,  0.29136434]],
#       shape=(15398, 4))

# %%
df_scaled = pd.DataFrame(scaled_features, 
                         columns=['yield_hg_ha', 'average_rain_fall_mm_per_year', 
                                  'pesticide_tonnes', 'avg_temp'])
