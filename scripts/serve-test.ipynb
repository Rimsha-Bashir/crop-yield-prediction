# %%
import requests

# %%
url = 'http://localhost:7860/predict'

# %%
data = {
        'country': 'hungary',
        'crop': 'potatoes',
        'year': 2010,
        'average_rain_fall_mm_per_year': 589,
        'pesticide_tonnes': 10299,
        'avg_temp': 10.35
    }

# %%
response=requests.post(url, json=data).json()
response
